# %% [markdown]
# <a href="https://colab.research.google.com/github/shalmalirao/ds3001-project1/blob/main/DS3001_Project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('hpatel')
# Out:
# hpatel
